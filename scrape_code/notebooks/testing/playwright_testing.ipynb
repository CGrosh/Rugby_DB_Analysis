# %%
import sys, os
_ROOT = os.path.abspath(os.path.join(os.getcwd(), '../..'))  # scrape_code/
sys.path.insert(0, os.path.join(_ROOT, 'scrapers'))
sys.path.insert(0, os.path.join(_ROOT, 'utils'))

# %%
import numpy as np 
import pandas as pd 
from scraper import scrape_model 
import os, sys, time, json, re
import requests 
import datetime, dateparser
from bs4 import BeautifulSoup
import base64
import brotli, gzip, zlib 

from playwright.sync_api import sync_playwright


test_url = "https://www.oddsportal.com/rugby-union/world/united-rugby-championship-2024-2025/results/"

# %%
with sync_playwright() as p:
    browser = p.chromium.launch(headless=False)  # Set headless=True for background
    page = browser.new_page()
    page.goto("https://example.com")
    print(page.title())
    browser.close()
